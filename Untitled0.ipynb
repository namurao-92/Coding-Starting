# %% [markdown]
# <a href="https://colab.research.google.com/github/namurao-92/Coding-Starting/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input('당신의 이름은')
# Out:
# 당신의 이름은 파이썬

# %%
name = input('당신의 별명은?')
# Out:
# 당신의 별명은?  pie

# %%
nick = "귀요미" # 'nick' 변수가 정의되지 않아 NameError가 발생했으므로 임시로 정의합니다.

# input() 함수는 하나의 프롬프트만 받으므로, 여러 인자를 출력하려면 print() 함수를 사용해야 합니다.
print(name, '의 별명은', nick, '입니다.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-834965418.py in <cell line: 0>()
# ----> 1 input(name, '의 별명은', nick, '입니다.')
#
# NameError: name 'nick' is not defined

# %% [markdown]
# Python 라이브러리는 `!pip install` 명령어를 사용하여 설치할 수 있습니다. 예를 들어, `numpy` 라이브러리를 설치하려면 다음 코드를 실행합니다:

# %%
# !pip install numpy

# %% [markdown]
# 설치된 라이브러리를 사용하려면 `import` 문을 사용합니다:

# %%
import numpy as np

# 이제 numpy를 사용할 수 있습니다.
print(np.__version__)
